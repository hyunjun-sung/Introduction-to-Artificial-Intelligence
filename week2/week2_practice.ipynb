# %%
import pandas as pd

# %%
# CSV 파일 불러오기
df = pd.read_csv(r"C:\Users\tjdgu\Programing_Study\AI_Introduction\week2\week2_assignment\titanic.csv")

df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Excel 파일 읽기
df = pd.read_excel(r"C:\Users\tjdgu\Programing_Study\AI_Introduction\week2\combined_dataset-1.xlsx")

df
# Out:
#      Num.  subject_ID Sex(M/F)  Age(year)  Height(cm)  Weight(kg)  \
# 0       1           2   Female         45         152          63
# 1       1           2   Female         45         152          63
# 2       1           2   Female         45         152          63
# 3       2           3   Female         50         157          50
# 4       2           3   Female         50         157          50
# ..    ...         ...      ...        ...         ...         ...
# 652   218         418     Male         25         173          63
# 653   218         418     Male         25         173          63
# 654   219         419     Male         24         175          58
# 655   219         419     Male         24         175          58
# 656   219         419     Male         24         175          58
#
#      Systolic Blood Pressure(mmHg)  Diastolic Blood Pressure(mmHg)  \
# 0                              161                              89
# ...

# %%
# 웹 주소에서 CSV 데이터 불러오기
df = pd.read_csv('https://raw.githubusercontent.com/MyungKyuYi/AI-class/main/titanic.csv')

df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
